# %% [markdown]
# <a href="https://colab.research.google.com/github/thofes/SJ_distance/blob/main/Prepare_Data_Resnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Connect GDrive
from google.colab import drive
drive.mount('/content.gdrive')
# Out:
# Mounted at /content.gdrive

# %%
#init Repository - YOLOv5
# %cd /content


# !git clone https://github.com/thofes/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install
# Out:
# /content
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5

# %%
# %cd /content/yolov5
landing_pic = '/content.gdrive/MyDrive/Dataset_Resnet/test/Flight'
Path_Result = '/content.gdrive/MyDrive/Data_Resnet_VAL'

# !python detect.py --weights "/content/yolov5/weights_skijumper_only.pt" --name Flight --save-crop --source {landing_pic} --project {Path_Result} --max-det 1
# Out:
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Dataset_Resnet/test/Flight, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Resnet_VAL, name=Flight, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-582-g288f8f1 Python-3.8.10 torch-1.13.1+cu116 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/232 /content.gdrive/MyDrive/Dataset_Resnet/test/Flight/10.jpg: 384x640 1 skijumper, 250.9ms
# image 2/232 /content.gdrive/MyDrive/Dataset_Resnet/test/Flight/100.jpg: 384x640 1 skijumper, 225.4ms
# ...

# %%
#danach durchgehen und reahpen 400x400
from PIL import Image
import os
PATH = '/content.gdrive/MyDrive/Data_Resnet_VAL/Landing'
label= []
try:
    label = next(os.walk(PATH))[2]
except StopIteration:
    pass
#data["labels"].append(label)
print(label)


for image in label:

# Öffnen Sie das Bild
    im = Image.open("/content.gdrive/MyDrive/Data_Resnet_VAL/Landing/" + str(image))





    if im.width < 400 or im.height < 400:
      # Vergrößern Sie das Bild um den Faktor 2
      im_resized = im.resize((400, 400), resample=Image.NEAREST)

      # Erstellen Sie eine neue schwarze Fläche, die die Größe des vergrößerten Bildes hat
      im_black = Image.new("RGB", (im_resized.width, im_resized.height), (255, 255, 255))

      # Fügen Sie das vergrößerte Bild in die Mitte der schwarzen Fläche ein
      im_black.paste(im_resized, (int((im_black.width - im_resized.width) / 2), int((im_black.height - im_resized.height) / 2)))

      # Speichern Sie das neue Bild
      im_black.save("/content.gdrive/MyDrive/Data_Resnet_VAL/Landing/" + str(image))
      print("/content.gdrive/MyDrive/Data_Resnet_VAL/Landing/" + str(image))
      
    else:
      print("OK")
# Out:
# ['101.jpg', '102.jpg', '103.jpg', '104.jpg', '105.jpg', '106.jpg', '107.jpg', '108.jpg', '109.jpg', '110.jpg', '111.jpg', '122.jpg', '123.jpg', '124.jpg', '125.jpg', '126.jpg', '127.jpg', '128.jpg', '129.jpg', '130.jpg', '131.jpg', '132.jpg', '14.jpg', '141.jpg', '142.jpg', '143.jpg', '144.jpg', '145.jpg', '146.jpg', '147.jpg', '148.jpg', '149.jpg', '15.jpg', '150.jpg', '151.jpg', '16.jpg', '162.jpg', '163.jpg', '164.jpg', '165.jpg', '166.jpg', '167.jpg', '168.jpg', '169.jpg', '17.jpg', '170.jpg', '171.jpg', '18.jpg', '182.jpg', '183.jpg', '184.jpg', '185.jpg', '186.jpg', '187.jpg', '188.jpg', '189.jpg', '19.jpg', '190.jpg', '191.jpg', '192.jpg', '2.jpg', '20.jpg', '203.jpg', '204.jpg', '205.jpg', '206.jpg', '207.jpg', '208.jpg', '209.jpg', '21.jpg', '210.jpg', '211.jpg', '212.jpg', '213.jpg', '22.jpg', '224.jpg', '225.jpg', '226.jpg', '227.jpg', '228.jpg', '229.jpg', '23.jpg', '230.jpg', '231.jpg', '232.jpg', '233.jpg', '234.jpg', '24.jpg', '245.jpg', '246.jpg', '247.jpg', '248.jpg'
# ...
