# %% [markdown]
# <a href="https://colab.research.google.com/github/thofes/SJ_distance/blob/main/TL_Landing_Sequence_Labeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Connect GDrive
from google.colab import drive
drive.mount('/content.gdrive')

#plots.py und 04_keypoints_from_images updaten

#init Repository - YOLOv5
# %cd /content


# !git clone https://github.com/thofes/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install
# Out:
# Mounted at /content.gdrive
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 13868, done.
# remote: Total 13868 (delta 0), reused 0 (delta 0), pack-reused 13868
# Receiving objects: 100% (13868/13868), 25.88 MiB | 29.71 MiB/s, done.
# Resolving deltas: 100% (9418/9418), done.
# /content/yolov5
#      |████████████████████████████████| 1.6 MB 26.1 MB/s

# %%
import os
import shutil
from os.path import exists, join, basename, splitext

save_counter = 1
index = 1


directory_label = 'labels'
directory_train = 'train'
directory_val = 'val'
parent_dir = '/content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence'
path_label = os.path.join(parent_dir, directory_label)
os.mkdir(path_label)

path_label_train = os.path.join(path_label, directory_train)
os.mkdir(path_label_train)

path_label_val = os.path.join(path_label, directory_val)
os.mkdir(path_label_val)


directory_images = 'images'
path_images = os.path.join(parent_dir, directory_images)
os.mkdir(path_images)

path_image_train = os.path.join(path_images, directory_train)
os.mkdir(path_image_train)

path_image_val = os.path.join(path_images, directory_val)
os.mkdir(path_image_val)




PATH = "/content.gdrive/MyDrive/Data_Pseudolabel"
label= []
try:
    label = next(os.walk(PATH))[1]
except StopIteration:
    pass
#data["labels"].append(label)
print(label)




for l in label:
  Path_jumpers = PATH + '/' + l
  print(Path_jumpers)
  Jumpers = []
  try:
    Jumpers = next(os.walk(Path_jumpers))[1]
  except StopIteration:
    pass
  print("Anzahl: " , len(Jumpers))
  

  for j in Jumpers:
    Path_Pic = Path_jumpers + '/' + j
    print(Path_Pic)
    landing_pic = Path_Pic + '/11.jpg'

    #Path_check = Path_Pic + '/exp'
    #if os.path.isdir(Path_check):


    # %cd /content/yolov5
    # !python detect.py --weights "/content/yolov5/weights_skijumper_only.pt" --save-crop --source {landing_pic} --project {Path_Pic} --save-txt --max-det 1

    if save_counter < 1400:
      shutil.copy(landing_pic, path_image_train + '/' + str(index) + '.jpg')
      shutil.copy(Path_Pic + '/exp2/labels/11.txt', path_label_train + '/' + str(index) + '.txt')

      print(path_image_train + '/' + str(index) + '.jpg')
      print(path_label_train + '/' + str(index) + '.txt')

    else:
      shutil.copy(landing_pic, path_image_val + '/' + str(index - 1199) + '.jpg')
      shutil.copy(Path_Pic + '/exp2/labels/11.txt', path_label_val + '/' + str(index - 1199) + '.txt') 

      print(path_image_val + '/' + str(index - 1199) + '.jpg')
      print(path_label_val + '/' + str(index - 1199) + '.txt')

    save_counter += 1   
    index += 1
# Out:
# ['hd4_runno']
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno
# Anzahl:  1805
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1799
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1799/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1799, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1799/11.jpg: 384x640 1 skijumper, 238.3ms
# Speed: 1.1ms pre-process, 238.3ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1799/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1799/exp2/labels
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/images/train/1.jpg
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/train/1.txt
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1797
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1797/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1797, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1797/11.jpg: 384x640 1 skijumper, 236.4ms
# Speed: 1.2ms pre-process, 236.4ms inference, 1.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1797/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1797/exp2/labels
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/images/train/2.jpg
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/train/2.txt
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/180
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/180/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/180, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/180/11.jpg: 384x640 1 skijumper, 371.8ms
# Speed: 1.5ms pre-process, 371.8ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno
6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/203/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/203/exp2/labels
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/images/train/221.jpg
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/train/221.txt
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/204
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/204/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/204, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/204/11.jpg: 384x640 1 skijumper, 226.3ms
# Speed: 1.1ms pre-process, 226.3ms inference, 0.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/204/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/204/exp2/labels
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/images/train/222.jpg
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/train/222.txt
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/209
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/209/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/209, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/209/11.jpg: 384x640 1 skijumper, 242.9ms
# Speed: 1.2ms pre-process, 242.9ms inference, 0.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/209/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/209/exp2/labels
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/images/train/223.jpg
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/train/223.txt
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/212
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/212/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/212, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/212/11.jpg: 384x640 1 skijumper, 225.6ms
# Speed: 1.2ms pre-process, 225.6ms inference, 0.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/212/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/212/exp2/labels
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/images/train/224.jpg
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/train/224.txt
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/218
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/218/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/218, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/218/11.jpg: 384x640 1 skijumper, 245.0ms
# Speed: 1.2ms pre-process, 245.0ms inference, 1.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/218/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/218/exp2/labels
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/images/train/225.jpg
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/train/225.txt
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/210
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/210/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/210, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/210/11.jpg: 384x640 1 skijumper, 223.8ms
# Speed: 1.1ms pre-process, 223.8ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/210/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/210/exp2/labels
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/images/train/226.jpg
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/train/226.txt
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/215
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/215/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/215, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/215/11.jpg: 384x640 (no detections), 233.4ms
# Speed: 1.2ms pre-process, 233.4ms inference, 0.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/215/exp2
# 0 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/215/exp2/labels
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-75e3c2908b20> in <module>
#      68     if save_counter < 1400:
#      69       shutil.copy(landing_pic, path_image_train + '/' + str(index) + '.jpg')
# ---> 70       shutil.copy(Path_Pic + '/exp2/labels/11.txt', path_label_train + '/' + str(index) + '.txt')
#      71
#      72       print(path_image_train + '/' + str(index) + '.jpg')
#
# /usr/lib/python3.7/shutil.py in copy(src, dst, follow_symlinks)
#     246     if os.path.isdir(dst):
#     247         dst = os.path.join(dst, os.path.basename(src))
# --> 248     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     249     copymode(src, dst, follow_symlinks=follow_symlinks)
#     250     return dst
#
# /usr/lib/python3.7/shutil.py in copyfile(src, dst, follow_symlinks)
#     118         os.symlink(os.readlink(src), dst)
#     119     else:
# --> 120         with open(src, 'rb') as fsrc:
#     121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/215/exp2/labels/11.txt'

# %%
# !python detect.py --weights "/content/yolov5/weights_skijumper_only.pt" --save-crop --source "/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1808/11.jpg" --project "/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1808/exp2" --save-txt --max-det 1
# Out:
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1808/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1808/exp2, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1808/11.jpg: 384x640 1 skijumper, 226.4ms
# Speed: 1.1ms pre-process, 226.4ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1808/exp2/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1808/exp2/exp2/labels

# %%
import shutil
landing_pic = "/content.gdrive/MyDrive/Try_4/NoTelemark/5/4.jpg"
path_image_train = "/content.gdrive/MyDrive/Try_4/NoTelemark/5"
index = 999
shutil.copy(landing_pic, path_image_train + '/' + str(index + 1) + '.jpg')
#shutil.copy("/content.gdrive/MyDrive/Try_4/NoTelemark/5/exp3/labels/5.txt", "/content.gdrive/MyDrive/Try_4/NoTelemark/5/exp3/labels/106.txt")
# Out:
# '/content.gdrive/MyDrive/Try_4/NoTelemark/5/1000.jpg'

# %%
import os

old_name = r"/content.gdrive/MyDrive/Try_4/NoTelemark/5/exp3/labels/1.txt"
new_name = r"/content.gdrive/MyDrive/Try_4/NoTelemark/5/exp3/labels/11.txt"
os.rename(old_name, new_name)
