# %% [markdown]
# <a href="https://colab.research.google.com/github/thofes/SJ_distance/blob/main/Yolo_TF_Label_Landezeitpunkt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Connect GDrive
from google.colab import drive
drive.mount('/content.gdrive')

#plots.py und 04_keypoints_from_images updaten

#init Repository - YOLOv5
# %cd /content


# !git clone https://github.com/thofes/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install
# Out:
# Mounted at /content.gdrive
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 13868, done.
# remote: Total 13868 (delta 0), reused 0 (delta 0), pack-reused 13868
# Receiving objects: 100% (13868/13868), 25.88 MiB | 29.71 MiB/s, done.
# Resolving deltas: 100% (9418/9418), done.
# /content/yolov5
#      |████████████████████████████████| 1.6 MB 26.1 MB/s

# %%
import os
import shutil
from os.path import exists, join, basename, splitext

save_counter = 227
index = 227


directory_label = 'labels'
directory_train = 'train'
directory_val = 'val'
parent_dir = '/content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence'
path_label = os.path.join(parent_dir, directory_label)
#os.mkdir(path_label)

path_label_train = os.path.join(path_label, directory_train)
#os.mkdir(path_label_train)

path_label_val = os.path.join(path_label, directory_val)
#os.mkdir(path_label_val)


directory_images = 'images'
path_images = os.path.join(parent_dir, directory_images)
#os.mkdir(path_images)

path_image_train = os.path.join(path_images, directory_train)
#os.mkdir(path_image_train)

path_image_val = os.path.join(path_images, directory_val)
#os.mkdir(path_image_val)




PATH = "/content.gdrive/MyDrive/Data_Pseudolabel"
label= []
try:
    label = next(os.walk(PATH))[1]
except StopIteration:
    pass
#data["labels"].append(label)
print(label)




for l in label:
  Path_jumpers = PATH + '/' + l
  print(Path_jumpers)
  Jumpers = []
  try:
    Jumpers = next(os.walk(Path_jumpers))[1]
  except StopIteration:
    pass
  print("Anzahl: " , len(Jumpers))
  

  for j in Jumpers:
    Path_Pic = Path_jumpers + '/' + j
    print(Path_Pic)
    landing_pic = Path_Pic + '/11.jpg'

    Path_check = Path_Pic + '/exp2'
    if os.path.isdir(Path_check):
      print("Done")

    else:

      # %cd /content/yolov5
      # !python detect.py --weights "/content/yolov5/weights_skijumper_only.pt" --save-crop --source {landing_pic} --project {Path_Pic} --save-txt --max-det 1

      if save_counter < 1400 and os.path.exists(Path_Pic + '/exp2/labels/11.txt'):
        shutil.copy(landing_pic, path_image_train + '/' + str(index) + '.jpg')
        shutil.copy(Path_Pic + '/exp2/labels/11.txt', path_label_train + '/' + str(index) + '.txt')

        print(path_image_train + '/' + str(index) + '.jpg')
        print(path_label_train + '/' + str(index) + '.txt')

      elif save_counter >= 1400 and os.path.exists(Path_Pic + '/exp2/labels/11.txt'):
        shutil.copy(landing_pic, path_image_val + '/' + str(index - 1199) + '.jpg')
        shutil.copy(Path_Pic + '/exp2/labels/11.txt', path_label_val + '/' + str(index - 1199) + '.txt') 

        print(path_image_val + '/' + str(index - 1199) + '.jpg')
        print(path_label_val + '/' + str(index - 1199) + '.txt')

      save_counter += 1   
      index += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/val/220.txt
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1443
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1443/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1443, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/
ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1788/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1788/exp2/labels
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/images/val/595.jpg
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/val/595.txt
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1789
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1789/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1789, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1789/11.jpg: 384x640 1 skijumper, 218.2ms
# Speed: 1.2ms pre-process, 218.2ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1789/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1789/exp2/labels
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/images/val/596.jpg
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/val/596.txt
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1794
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1794/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1794, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1794/11.jpg: 384x640 1 skijumper, 234.2ms
# Speed: 1.1ms pre-process, 234.2ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1794/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1794/exp2/labels
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/images/val/597.jpg
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/val/597.txt
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/179
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/179/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/179, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/179/11.jpg: 384x640 1 skijumper, 222.2ms
# Speed: 1.1ms pre-process, 222.2ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/179/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/179/exp2/labels
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/images/val/598.jpg
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/val/598.txt
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1792
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1792/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1792, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1792/11.jpg: 384x640 1 skijumper, 224.1ms
# Speed: 1.2ms pre-process, 224.1ms inference, 1.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1792/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1792/exp2/labels
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/images/val/599.jpg
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/val/599.txt
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1790
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1790/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1790, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1790/11.jpg: 384x640 1 skijumper, 223.6ms
# Speed: 1.2ms pre-process, 223.6ms inference, 1.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1790/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1790/exp2/labels
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/images/val/600.jpg
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/val/600.txt
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1801
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1801/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1801, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1801/11.jpg: 384x640 1 skijumper, 239.4ms
# Speed: 1.2ms pre-process, 239.4ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1801/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1801/exp2/labels
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/images/val/601.jpg
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/val/601.txt
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1800
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1800/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1800, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1800/11.jpg: 384x640 1 skijumper, 245.6ms
# Speed: 1.3ms pre-process, 245.6ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1800/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1800/exp2/labels
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/images/val/602.jpg
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/val/602.txt
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1798
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1798/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1798, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1798/11.jpg: 384x640 1 skijumper, 226.2ms
# Speed: 1.3ms pre-process, 226.2ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1798/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1798/exp2/labels
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/images/val/603.jpg
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/val/603.txt
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1805
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1805/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1805, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1805/11.jpg: 384x640 1 skijumper, 225.8ms
# Speed: 1.2ms pre-process, 225.8ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1805/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1805/exp2/labels
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/images/val/604.jpg
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/val/604.txt
# /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1802
# /content/yolov5
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1802/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1802, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1802/11.jpg: 384x640 1 skijumper, 219.1ms
# Speed: 1.2ms pre-process, 219.1ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1802/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1802/exp2/labels
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/images/val/605.jpg
# /content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/val/605.txt

# %%
# !python detect.py --weights "/content/yolov5/weights_skijumper_only.pt" --save-crop --source "/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1808/11.jpg" --project "/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1808/exp2" --save-txt --max-det 1
# Out:
# detect: weights=['/content/yolov5/weights_skijumper_only.pt'], source=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1808/11.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1808/exp2, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.1-578-ge4fa487 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1808/11.jpg: 384x640 1 skijumper, 226.4ms
# Speed: 1.1ms pre-process, 226.4ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1808/exp2/exp2
# 1 labels saved to /content.gdrive/MyDrive/Data_Pseudolabel/hd4_runno/1808/exp2/exp2/labels

# %%
import shutil
landing_pic = "/content.gdrive/MyDrive/Try_4/NoTelemark/5/4.jpg"
path_image_train = "/content.gdrive/MyDrive/Try_4/NoTelemark/5"
index = 999
shutil.copy(landing_pic, path_image_train + '/' + str(index + 1) + '.jpg')
#shutil.copy("/content.gdrive/MyDrive/Try_4/NoTelemark/5/exp3/labels/5.txt", "/content.gdrive/MyDrive/Try_4/NoTelemark/5/exp3/labels/106.txt")
# Out:
# '/content.gdrive/MyDrive/Try_4/NoTelemark/5/1000.jpg'

# %%
import os

path = "/content.gdrive/MyDrive/Transfer_Learning_Landing_Sequence/labels/train/1356.txt"

print(os.path.exists(path))
# Out:
# False
