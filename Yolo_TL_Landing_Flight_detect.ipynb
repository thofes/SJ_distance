# %% [markdown]
# <a href="https://colab.research.google.com/github/thofes/SJ_distance/blob/main/Yolo_TL_Landing_Flight_detect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content.gdrive')
# Out:
# Mounted at /content.gdrive

# %%
import os
PATH = "/content.gdrive/MyDrive/TL_Flug_Landung_big/images/val"
jumper = []
try:
    jumper = next(os.walk(PATH))[2]
except StopIteration:
    pass

print("Anzahl: " , len(jumper))
#Ordner der Lables
print(jumper)
# Out:
# Anzahl:  2000
# ...

# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14906, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 14906 (delta 11), reused 12 (delta 2), pack-reused 14880
# Receiving objects: 100% (14906/14906), 13.92 MiB | 26.02 MiB/s, done.
# Resolving deltas: 100% (10258/10258), done.
# /content/yolov5
#      |████████████████████████████████| 182 kB 30.1 MB/s
#      |████████████████████████████████| 62 kB 1.0 MB/s
#      |████████████████████████████████| 1.6 MB 47.1 MB/s

# %%
# %cd /content/yolov5
# !python train.py --weights yolov5s.pt --data '/content.gdrive/MyDrive/TL_Flug_Landung_big/skijumper.yaml' --epochs 20 --batch -1 #--cache
# Out:
# /content/yolov5
# train: weights=yolov5s.pt, cfg=, data=/content.gdrive/MyDrive/TL_Flug_Landung_big/skijumper.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=-1, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-53-g65071da Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
import shutil
shutil.copy('/content/yolov5/runs/train/exp/weights/best.pt', '/content.gdrive/MyDrive/TL_Flug_Landung_big')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-799d8121f5f8> in <module>
#       1 import shutil
# ----> 2 shutil.copy('/content/yolov5/runs/train/exp/weights/best.pt', '/content.gdrive/MyDrive/TL_Flug_Landung_big')
#
# /usr/lib/python3.8/shutil.py in copy(src, dst, follow_symlinks)
#     416     if os.path.isdir(dst):
#     417         dst = os.path.join(dst, os.path.basename(src))
# --> 418     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     419     copymode(src, dst, follow_symlinks=follow_symlinks)
#     420     return dst
#
# /usr/lib/python3.8/shutil.py in copyfile(src, dst, follow_symlinks)
#     262         os.symlink(os.readlink(src), dst)
#     263     else:
# --> 264         with open(src, 'rb') as fsrc, open(dst, 'wb') as fdst:
#     265             # macOS
#     266             if _HAS_FCOPYFILE:
#
# ...

# %%
# %cd /content/yolov5
# !python detect.py --weights "/content.gdrive/MyDrive/Vorselektion/Flight_Landing_big/best_landing_flight_11.pt" --name 'Test_all' --save-crop --source '/content.gdrive/MyDrive/Vorselektion/B-Hofen_Samples_Label/29' --project '/content.gdrive/MyDrive/Vorselektion/Flight_Landing_big/29' --save-txt #--max-det 1
# Out:
# /content/yolov5
# detect: weights=['/content.gdrive/MyDrive/Vorselektion/Flight_Landing_big/best_landing_flight_11.pt'], source=/content.gdrive/MyDrive/Vorselektion/B-Hofen_Samples_Label/29, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Vorselektion/Flight_Landing_big/29, name=Test_all, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-53-g65071da Python-3.8.16 torch-1.13.0+cu116 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/808 /content.gdrive/MyDrive/Vorselektion/B-Hofen_Samples_Label/29/Cam1_0000.jpg: 384x640 (no detections), 228.2ms
# ...
