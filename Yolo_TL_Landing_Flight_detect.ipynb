# %% [markdown]
# <a href="https://colab.research.google.com/github/thofes/SJ_distance/blob/main/Yolo_TL_Landing_Flight_detect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content.gdrive')
# Out:
# Mounted at /content.gdrive

# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14302, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 14302 (delta 25), reused 39 (delta 17), pack-reused 14246
# Receiving objects: 100% (14302/14302), 13.57 MiB | 23.62 MiB/s, done.
# Resolving deltas: 100% (9835/9835), done.
# /content/yolov5
#      |████████████████████████████████| 182 kB 5.1 MB/s
#      |████████████████████████████████| 62 kB 1.3 MB/s
#      |████████████████████████████████| 1.6 MB 61.2 MB/s

# %%
# %cd /content/yolov5
# !python train.py --weights yolov5s.pt --data '/content.gdrive/MyDrive/TL_Landing_2/skijumper.yaml' --epochs 50 --batch -1 #--cache
# Out:
# /content/yolov5
# Traceback (most recent call last):
#   File "train.py", line 42, in <module>
#     import val as validate  # for end-of-epoch mAP
#   File "/content/yolov5/val.py", line 38, in <module>
#     from models.common import DetectMultiBackend
#   File "/content/yolov5/models/common.py", line 29, in <module>
#     from utils.dataloaders import exif_transpose, letterbox
#   File "/content/yolov5/utils/dataloaders.py", line 31, in <module>
#     from utils.augmentations import (Albumentations, augment_hsv, classify_albumentations, classify_transforms, copy_paste,
#   File "/content/yolov5/utils/augmentations.py", line 15, in <module>
#   File "/content/yolov5/utils/general.py", line 34, in <module>
#     import pkg_resources as pkg
#   File "/usr/local/lib/python3.8/dist-packages/pkg_resources/__init__.py", line 3243, in <module>
#     def _initialize_master_working_set():
#   File "/usr/local/lib/python3.8/dist-packages/pkg_resources/__init__.py", line 3226, in _call_aside
# ...

# %%
import shutil
shutil.copy('/content/yolov5/runs/train/exp2/weights/best.pt', '/content.gdrive/MyDrive/TL_Landing_2')
# Out:
# '/content.gdrive/MyDrive/TL_Landing_2/best.pt'

# %%
# %cd /content/yolov5
# !python detect.py --weights "/content.gdrive/MyDrive/TL_Landing_2/skijumper_flight_landing.pt" --name 'Test_all' --save-crop --source '/content.gdrive/MyDrive/Showroom/Bilder Ewoxx neu/89' --project '/content.gdrive/MyDrive/Showroom/Bilder Ewoxx neu/89' --save-txt #--max-det 1
# Out:
# /content/yolov5
# detect: weights=['/content.gdrive/MyDrive/TL_Landing_2/skijumper_flight_landing.pt'], source=/content.gdrive/MyDrive/Showroom/Bilder Ewoxx neu/89, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content.gdrive/MyDrive/Showroom/Bilder Ewoxx neu/89, name=Test_all, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-12-g7f5724b Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/698 /content.gdrive/MyDrive/Showroom/Bilder Ewoxx neu/89/Cam1_0000.jpg: 384x640 (no detections), 12.5ms
# ...
